# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.dates import date2num
import datetime

# %%
emb_results = pd.read_csv("../results/uniprot/embedding_comparison.csv")
# emb_results

# %%
def autolabel(rects):
    """
    Attach a text label above each bar displaying its height
    """
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width() / 2., 1.01 * height,
                '%.2f' % float(height),
                ha='center', va='bottom')

# %%
x = emb_results["family"]
_x = np.arange(len(x))
y = emb_results.iloc[:, 1] * 100.0
z = emb_results.iloc[:, 4] * 100.0
# k=[11,12,13]
plt.close("all")
plt.figure(figsize=(15, 15))
ax = plt.subplot(111)

rects1 = ax.bar(_x, y,width=0.4,align='center', label= "Freq2Vec")
rects2 = ax.bar(_x-.4, z,width=0.4,align='center', label="Skipgram")
# ax.bar(_x, t,width=0.2,align='center', label= "Stratfied 5-fold")
# rects = ax.bar(_x+.2, k,width=0.2,align='center', label="Stratified 10-fold")
autolabel(rects1)
# autolabel(rects2)


# ax.xaxis_date()
ax.legend()
plt.yticks(np.arange(0, 105, 5))
plt.xticks(_x, x, rotation=90)
plt.grid()
plt.title("Embedding Comparison in protein family classification")
plt.savefig("../results/uniprot/embedding_comparison.pdf")
plt.show()
